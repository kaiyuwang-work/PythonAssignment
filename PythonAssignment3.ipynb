# %%
import re

data = open('sample_toronto_sales.csv','r')
read_table = data.readlines()
data.close()

#------method dealing with address formatting---
#get rid of '#' and '-' starting for index 1 
def addressformatting(address):
    unit,firstletter,block = re.split('([a-zA-Z])',address,1)
    #use regex to further split unit number and block number
    while unit[-1:] == ' ':
        unit = unit[:-1]
    if unit[:1] == '#':
        unit = unit[1:]
        if " - " in unit:
            unit = unit.replace(' - ','-')
        if " -" in unit:
            unit = unit.replace(' -','-')
            unit = unit.replace('- ','-')
    else:
        unit = unit.replace(" ","-")
        
    block = (firstletter+block).title()
    return unit+ ' ' +block


#------process data into list and dict---
table = []

for line in range(1,len(read_table),1):
    #split each line by ','
    address,price = read_table[line].split(',')
    address = addressformatting(address)
    price = int(price[:-2])
    #store address and price into a list
    table.extend([[address,price]])
    

print("The LIST is now containing %d rows" % len(table))
#transfer list to dictionary
dict_table = dict(table)
print("The DICTIONARY is now containing %d rows" % len(dict_table))
#the reason that lenght of dict is shorter than list is becuase there are same key(address) values, and dict don't store same key value.
print("The reason that lengh of dict is shorter than list is becuase"+"there are same key(address) values, and dict don't store same key value.".upper()+"\n")



#calculate windchill
def windchill(temperature, windspeed):
    windchill = 13.12+(0.6215*temperature)-(11.37*windspeed**0.16)+(0.3965*temperature*windspeed**0.16)
    return windchill

#------outprint---
for temperature in range(-35,11,5):
    print("temperature is %d" % temperature)
    for windspeed in range(0,81,5):
        print("\twindspeed is "  + str(windspeed)+" caculated wind chill is: "+ str(int(windchill(temperature, windspeed))))
# Out:
# The LIST is now containing 94 rows
# The DICTIONARY is now containing 82 rows
# The reason that lengh of dict is shorter than list is becuaseTHERE ARE SAME KEY(ADDRESS) VALUES, AND DICT DON'T STORE SAME KEY VALUE.
#
# temperature is -35
# 	windspeed is 0 caculated wind chill is: -8
# 	windspeed is 5 caculated wind chill is: -41
# 	windspeed is 10 caculated wind chill is: -45
# 	windspeed is 15 caculated wind chill is: -47
# 	windspeed is 20 caculated wind chill is: -49
# 	windspeed is 25 caculated wind chill is: -50
# 	windspeed is 30 caculated wind chill is: -52
# 	windspeed is 35 caculated wind chill is: -53
# 	windspeed is 40 caculated wind chill is: -54
# 	windspeed is 45 caculated wind chill is: -55
# 	windspeed is 50 caculated wind chill is: -55
# 	windspeed is 55 caculated wind chill is: -56
# 	windspeed is 60 caculated wind chill is: -57
# 	windspeed is 65 caculated wind chill is: -57
# 	windspeed is 70 caculated wind chill is: -58
# 	windspeed is 75 caculated wind chill is: -59
# 	windspeed is 80 caculated wind chill is: -59
# temperature is -30
# 	windspeed is 0 caculated wind chill is: -5
# 	windspeed is 5 caculated wind chill is: -35
# 	windspeed is 10 caculated wind chill is: -39
# 	windspeed is 15 caculated wind chill is: -41
# 	windspeed is 20 caculated wind chill is: -43
# 	windspeed is 25 caculated wind chill is: -44
# 	windspeed is 30 caculated wind chill is: -45
# 	windspeed is 35 caculated wind chill is: -46
# 	windspeed is 40 caculated wind chill is: -47
# 	windspeed is 45 caculated wind chill is: -48
# 	windspeed is 50 caculated wind chill is: -49
# 	windspeed is 55 caculated wind chill is: -49
# 	windspeed is 60 caculated wind chill is: -50
# 	windspeed is 65 caculated wind chill is: -50
# 	windspeed is 70 caculated wind chill is: -51
